# %% [markdown]
# <a href="https://colab.research.google.com/github/Mittssyymaniac/Language_Traslation/blob/main/rnn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import SimpleRNN, Dense
import numpy as np

X = np.random.random((100, 10, 1))  # 100 samples, 10 time steps, 1 feature
y = np.random.randint(2, size=(100, 1))

model = Sequential([
    SimpleRNN(16, input_shape=(10, 1)),
    Dense(1, activation='sigmoid')
])

model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
model.fit(X, y, epochs=10)

# %% [markdown]
# <a href="https://colab.research.google.com/github/Mittssyymaniac/Language_Traslation/blob/main/sdpta.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# Input and expected output for AND gate
X = np.array([[0,0], [0,1], [1,0], [1,1]])
Y = np.array([0, 0, 0, 1])  # AND gate output

# Initialize weights and bias
weights = np.zeros(2)
bias = 0
lr = 1  # learning rate
epochs = 10

def step_function(y):
    return 1 if y >= 0 else 0

# Training loop
for epoch in range(epochs):
    print(f"Epoch {epoch+1}")
    for i in range(len(X)):
        y_in = np.dot(X[i], weights) + bias
        y_pred = step_function(y_in)
        error = Y[i] - y_pred
        weights += lr * error * X[i]
        bias += lr * error
        print(f"Input: {X[i]}, Predicted: {y_pred}, Error: {error}, Weights: {weights}, Bias: {bias}")

print("\nFinal Weights:", weights)
print("Final Bias:", bias)
